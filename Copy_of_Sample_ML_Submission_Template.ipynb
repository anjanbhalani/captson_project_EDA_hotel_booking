# %% [markdown]
# <a href="https://colab.research.google.com/github/anjanbhalani/captson_project_EDA_hotel_booking/blob/mainn/Copy_of_Sample_ML_Submission_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -Unsupervised ML - Netflix Movies and TV Shows Clustering

# %% [markdown]
# ##### **Project Type**    - Unsupervised
# ##### **Contribution**    - Individual
# ##### **Name**            - Bhalani Anjankumar V.

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The objective of this project is to analyze and cluster a dataset related to Netflix. The dataset consists of various attributes associated with Netflix shows and movies, such as title, genre, release year, duration, rating, and others. The aim is to explore patterns and similarities among the content available on the platform and group them into meaningful clusters.
#
# To begin with, the dataset will be preprocessed by handling missing values, removing irrelevant columns, and transforming categorical variables into numerical representations. Feature engineering techniques may also be applied to extract useful information from the existing attributes.
#
# Next, exploratory data analysis (EDA) techniques will be utilized to gain insights into the dataset. Visualizations and statistical summaries will be used to understand the distribution of variables, identify any trends, and explore relationships between different features.
#
# Once the dataset has been thoroughly analyzed, clustering algorithms such as k-means, hierarchical clustering, or density-based spatial clustering will be employed. These algorithms will group similar Netflix shows and movies together based on their attributes. The optimal number of clusters will be determined using techniques like the elbow method or silhouette analysis.
#
# After the clustering process, the results will be evaluated and interpreted. The clusters will be analyzed to understand the common characteristics and patterns within each group. This analysis will provide valuable information for Netflix in terms of content categorization, recommendation systems, and content acquisition strategies.
#
# Finally, the findings and insights from the clustering analysis will be summarized and presented in a clear and concise manner. Visualizations, charts, and graphs will be used to effectively communicate the outcomes of the project. Recommendations may also be provided based on the identified clusters, suggesting potential improvements or strategies for Netflix to enhance user experience and content offerings.
#
# In conclusion, this project aims to analyze a Netflix dataset, perform clustering techniques to group similar shows and movies together, and provide insights and recommendations based on the clustering results. The project will contribute to a better understanding of Netflix's content landscape and aid in decision-making processes for the company.
# write in different word
#
# ChatGPT
# The goal of this project is to explore and categorize a dataset containing information about Netflix shows and movies. The dataset includes various attributes like title, genre, release year, duration, and rating. Our objective is to uncover patterns and similarities among the content available on Netflix and organize them into meaningful clusters.
#
# To start, we'll preprocess the dataset by addressing missing values, eliminating irrelevant columns, and converting categorical variables into numerical representations. We'll also perform feature engineering to extract valuable insights from the existing attributes.
#
# Following preprocessing, we'll conduct exploratory data analysis (EDA) to gain deeper insights. Through visualizations and statistical summaries, we'll examine variable distributions, identify trends, and explore relationships between different features.
#
# Next, we'll apply clustering algorithms such as k-means, hierarchical clustering, or density-based spatial clustering to group similar Netflix shows and movies together based on their attributes. We'll determine the optimal number of clusters using techniques like the elbow method or silhouette analysis.
#
# After clustering, we'll evaluate and interpret the results. We'll analyze the characteristics and patterns within each cluster to understand common themes. This analysis will offer valuable insights for Netflix in terms of content categorization, recommendation systems, and content acquisition strategies.
#
# Finally, we'll summarize and present our findings in a clear and concise manner using visualizations, charts, and graphs. We may also provide recommendations based on the identified clusters to suggest potential improvements or strategies for Netflix to enhance user experience and content offerings.
#
# In summary, this project seeks to analyze a Netflix dataset, utilize clustering techniques to group similar content, and offer insights and recommendations to enhance Netflix's content landscape and decision-making processes.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/anjanbhalani/captson_project_EDA_hotel_booking/blob/main/Copy_of_Sample_ML_Submission_Template.ipynb

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **The dataset contains information about TV shows and movies available on Netflix as of 2019. According to a report from Flixable, a third-party Netflix search engine, the number of TV shows on Netflix has almost tripled since 2010. Conversely, the number of movies on the streaming service has decreased by over 2,000 titles since 2010, while the quantity of TV shows has nearly tripled. This dataset presents an opportunity to extract additional valuable insights beyond these findings.**

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 15 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]
#
#
#
#
#
# 6. You may add more ml algorithms for model creation. Make sure for each and every algorithm, the following format should be answered.
#
#
# *   Explain the ML Model used and it's performance using Evaluation metric Score Chart.
#
#
# *   Cross- Validation & Hyperparameter Tuning
#
# *   Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.
#
# *   Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
from numpy import math
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
from matplotlib.pyplot import figure
import plotly.graph_objects as go
import plotly.offline as py
import plotly.express as px
from datetime import datetime

import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
from plotly.offline import init_notebook_mode, iplot
import plotly.offline as po
import plotly.io as pio

from collections import Counter
from sklearn import preprocessing
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split, KFold
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
from sklearn.decomposition import PCA

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Dataset Loading

# %%
pip install -U kaleido

# %%
# Load Dataset
netflix_movies1 = pd.read_csv('/content/NETFLIX MOVIES AND TV SHOWS CLUSTERING.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
netflix_movies1.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
# 3  November 16, 2017          2009  PG-13     80 min
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print("rows :",netflix_movies1.shape[0])
print("columns : ",netflix_movies1.shape[1])
# Out:
# rows : 7787
# columns :  12

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
netflix_movies1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7787 non-null   object
#  1   type          7787 non-null   object
#  2   title         7787 non-null   object
#  3   director      5398 non-null   object
#  4   cast          7069 non-null   object
#  5   country       7280 non-null   object
#  6   date_added    7777 non-null   object
#  7   release_year  7787 non-null   int64
#  8   rating        7780 non-null   object
#  9   duration      7787 non-null   object
#  10  listed_in     7787 non-null   object
#  11  description   7787 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 730.2+ KB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
netflix_movies1.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
netflix_movies1.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2389
# cast             718
# country          507
# date_added        10
# release_year       0
# rating             7
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
# Visualizing the missing values
sns.heatmap(netflix_movies1.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
#handle missing values
netflix_movies1['cast'].fillna(value='No cast',inplace=True)
netflix_movies1['country'].fillna(value=netflix_movies1['country'].mode()[0],inplace=True)

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# This dataset contain information about various TV shows and movies available on Netflix, including details like the production country, release year, rating, duration, genre, and a description of each title. It consists of 12 columns and 7787 rows.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
netflix_movies1.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
# Dataset Describe
netflix_movies1.describe(include='all')
# Out:
#        show_id   type title                director     cast        country  \
# count     7787   7787  7787                    5398     7787           7787
# unique    7787      2  7787                    4049     6832            681
# top         s1  Movie    3%  Raúl Campos, Jan Suter  No cast  United States
# freq         1   5377     1                      18      718           3062
# mean       NaN    NaN   NaN                     NaN      NaN            NaN
# std        NaN    NaN   NaN                     NaN      NaN            NaN
# min        NaN    NaN   NaN                     NaN      NaN            NaN
# 25%        NaN    NaN   NaN                     NaN      NaN            NaN
# 50%        NaN    NaN   NaN                     NaN      NaN            NaN
# 75%        NaN    NaN   NaN                     NaN      NaN            NaN
# max        NaN    NaN   NaN                     NaN      NaN            NaN
#
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# **Attribute Information**
#
# **show_id :** Unique ID for every Movie / Tv Show
#
# **type :** Identifier - A Movie or TV Show
#
# **title :** Title of the Movie / Tv Show
#
# **director :** Director of the Movie
#
# **cast :** Actors involved in the movie / show
#
# **country :** Country where the movie / show was produced
#
# **date_added :** Date it was added on Netflix
#
# **release_year :** Actual Releaseyear of the movie / show
#
# **rating :** TV Rating of the movie / show
#
# **duration :** Total Duration - in minutes or number of seasons
#
# **listed_in :** Genere
#
# ***description:*** The Summary description

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
print(netflix_movies1.apply(lambda col: col.unique()))
# Out:
# show_id         [s1, s2, s3, s4, s5, s6, s7, s8, s9, s10, s11,...
# type                                             [TV Show, Movie]
# title           [3%, 7:19, 23:59, 9, 21, 46, 122, 187, 706, 19...
# director        [nan, Jorge Michel Grau, Gilbert Chan, Shane A...
# cast            [João Miguel, Bianca Comparato, Michel Gomes, ...
# country         [Brazil, Mexico, Singapore, United States, Tur...
# date_added      [August 14, 2020, December 23, 2016, December ...
# release_year    [2020, 2016, 2011, 2009, 2008, 2019, 1997, 201...
# rating          [TV-MA, R, PG-13, TV-14, TV-PG, NR, TV-G, TV-Y...
# duration        [4 Seasons, 93 min, 78 min, 80 min, 123 min, 1...
# listed_in       [International TV Shows, TV Dramas, TV Sci-Fi ...
# description     [In a future where the elite inhabit an island...
# dtype: object

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# Create new features to store date, day, month and year seperately.
netflix_movies1["date_added"] = pd.to_datetime(netflix_movies1['date_added'], errors='coerce')
netflix_movies1['day_added'] = netflix_movies1['date_added'].dt.day            # Compute day.
netflix_movies1['year_added'] = netflix_movies1['date_added'].dt.year          # Compute year.
netflix_movies1['month_added'] = netflix_movies1['date_added'].dt.month        # Compute month.

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Insights from the dataset include missing data in the "Director," "Country," "Cast," and "Date Added" columns, which have been handled by filling in or extracting information. Duplication in the dataset has been identified, and unique values in each column have been determined. Additionally, the "Date Added" column has been parsed to extract details like the day, month, and year, shedding light on the temporal aspects of the dataset.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
import plotly.graph_objects as go
import pandas as pd
tv_show = netflix_movies1[netflix_movies1["type"] == "TV Show"]
movie = netflix_movies1[netflix_movies1["type"] == "Movie"]

col = "year_added"

content_1 = tv_show["year_added"].value_counts().sort_index()
content_2 = movie["year_added"].value_counts().sort_index()

trace1 = go.Scatter(x=content_1.index, y=content_1.values, name="TV Shows", marker=dict(color='#008000', line=dict(width=4)))
trace2 = go.Scatter(x=content_2.index, y=content_2.values, name="Movies", marker=dict(color='#ffd700', line=dict(width=4)))

fig = go.Figure(data=[trace1, trace2], layout=go.Layout(title="Content added over the years",title_x=0.5, legend=dict(x=0.8, y=1.1, orientation="h")))
# Display chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The line chart is well-suited for illustrating the changing pattern and spread of data across a continuous axis, in this instance, spanning across years. It facilitates straightforward comparisons between TV shows and movies, offering insight into how their respective quantities fluctuate over the years.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The trend in the visualization indicates that between 2008 and 2022, there were relatively fewer TV shows and movies added to Netflix. However, starting from 2016, there was a slight increase in content additions. In 2019, there was a significant peak in the number of movies added, while TV shows experienced a similar trend but with a lesser increase compared to movies.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights indicate a positive impact for Netflix as the demand for both TV shows and movies on the platform has been increasing rapidly over the years. This growth presents an opportunity for Netflix to provide more high-quality content to its users, thereby enhancing user satisfaction and engagement.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
labels = ['TV Show', 'Movie']
values = [netflix_movies1.type.value_counts()[1], netflix_movies1.type.value_counts()[0]]

# Colors
colors = ['#ffd700', '#008000']

# Create pie chart
fig = go.Figure(data=[go.Pie(labels=labels, values=values, hole=.6)])

# Customize layout
fig.update_layout(
    title_text='Type of Content Watched on Netflix',
    title_x=0.5,
    height=500,
    width=500,
    legend=dict(x=0.9),
    annotations=[dict(text='Type of Content', font_size=20, showarrow=False)]
)

# Set colors
fig.update_traces(marker=dict(colors=colors))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The specific chart used in the code is a pie chart. I picked this chart because it is effective in visualizing the distribution of categorical data. In this case, the chart is used to represent the types of content watched on Netflix, which are categorized as "TV Show" and "Movie

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# TV shows constitute the majority, accounting for 69.1% of the content watched on Netflix, while movies make up a smaller percentage of 30.9%.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The data indicates a clear preference for TV shows over movies, with a significantly higher percentage of 69.1% compared to the lower percentage of 30.9% for movies. This suggests that people tend to enjoy shorter formats like TV shows rather than investing their time in longer movies that may be less engaging.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
import matplotlib.pyplot as plt
import seaborn as sns
fig, ax = plt.subplots(figsize=(15,6))
sns.countplot(x='month_added', hue='type',lw=5, data=netflix_movies1, ax=ax,palette=['#FF0000' ,'#0000FF'])
# Out:
# <Axes: xlabel='month_added', ylabel='count'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# By using a countplot, we can easily see and compare the frequencies of TV show and movie additions for each month.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Movies:
#
# January, October, and December appear to be the trending months for movie additions on Netflix compared to other months.
#
# Tv Shows:
#
# October, November, and December emerge as the trending months for TV show ad

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights regarding the trending months for movies and TV shows on Netflix can potentially create a positive business impact. Here's why:
#
# 1-Meeting Viewer Demand:
#
# 2-Capitalizing on Seasonal Trends:
#
# 3-Improved Competitiveness:

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
#Checking the distribution of Movie Durations
plt.figure(figsize=(10,7))
#Regular Expression pattern \d is a regex pattern for digit + is a regex pattern for at leas
sns.distplot(movie['duration'].str.extract('(\d+)'),kde=False, color=['red'])
plt.title('Distplot with Normal distribution for Movies and Tv shows',fontweight="bold")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The Distplot is a suitable choice for this analysis because it allows us to observe the frequency or count of movies falling into different duration ranges.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The average length of movies and TV shows falling within the range of 50 to 150 minutes can vary depending on the specific content available on Netflix.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
#
# 1-Audience Flexibility : By offering movies and TV shows with a variety of lengths, ranging from shorter films to longer epic productions, Netflix can cater to the diverse preferences and schedules of its audience
#
# 2-Increased Engagement : Movies and TV shows with varying lengths provide options for viewers to choose content that fits their available time. This can lead to increased engagement and longer viewing sessions
#
# 3-Content Diversity : By including movies and TV shows of different lengths, Netflix can expand its content library and cater to various genres and storytelling formats.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
#Checking the distribution of TV SHOWS
plt.figure(figsize=(20,8))
plt.title("Distribution of TV Shows duration",fontweight='bold')
sns.countplot(x=tv_show['duration'],data=tv_show,order = tv_show['duration'].value_counts().index)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The chart in question is a countplot, which is a type of bar chart that shows the frequency or count of each category in a categorical variable. It seems to be used to display the distribution of TV show seasons

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the chart, we observed that the majority of TV shows or web series in the dataset have only one season, while the remaining shows have a maximum of two, three, four, or five seasons.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes ,Positive Impact because by recognizing that the majority of TV shows have a limited number of seasons, content producers and streaming platforms can optimize their production planning. They can allocate resources more efficiently, reduce production costs, and potentially increase the output of content.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
movie['originals'] = np.where(movie['release_year'] == movie['year_added'], 'Yes', 'No')
# pie plot showing percentage of originals and others in movies
fig, ax = plt.subplots(figsize=(5,5),facecolor="#660066")
ax.patch.set_facecolor("#660066")
explode = (0, 0.1)
ax.pie(movie['originals'].value_counts(), explode=explode, autopct='%.2f%%', labels= ['Others', 'Originals'],
       shadow=True, startangle=90,textprops={'color':"blue", 'fontsize': 25}, colors =['red','#F5E9F5'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7c91ed2f7640>,
# ...
#  [Text(-0.8902585632950727, -0.6460957285726268, 'Others'),
#   Text(0.9711911599582614, 0.7048317038974106, 'Originals')],
#  [Text(-0.4855955799791305, -0.3524158519487055, '69.98%'),
#   Text(0.5665281766423191, 0.4111518272734894, '30.02%')])

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The pie plot is a suitable choice for visualizing the distribution of categorical data, such as the proportion of "originals" and "others" in this case. It allows you to see the relative sizes of each category as a portion of the whole.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Out of the movies available on Netflix, 30% are Netflix originals, while the remaining 70% are movies that were released earlier through different distribution channels and subsequently added to the Netflix

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, gaining insights can indeed help create a positive business impact. By understanding the distribution of movies on Netflix, such as the proportion of Netflix originals versus non-originals, the streaming service can make informed decisions about content acquisition and production.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
netflix_movies1['cast']
# seperating actors from cast column
cast = netflix_movies1['cast'].str.split(', ', expand=True).stack()

# top actors name who play highest role in movie/show.
cast.value_counts()
cast =cast[cast != 'No cast']
cast.value_counts()

fig,ax = plt.subplots(1,2, figsize=(14,5))

# seperating TV shows actor from cast column
top_TVshows_actor = netflix_movies1[netflix_movies1['type']=='TV Show']['cast'].str.split(', ', expand=True).stack()
top_TVshows_actor =top_TVshows_actor[top_TVshows_actor != 'No cast']
# plotting actor who appeared in highest number of TV Show
a = top_TVshows_actor.value_counts().head(10).plot(kind='barh', ax=ax[0],color='red')
a.set_title('Top 10 TV shows actors', size=15)

# seperating movie actor from cast column
top_movie_actor = netflix_movies1[netflix_movies1['type']=='Movie']['cast'].str.split(', ', expand=True).stack()
top_movie_actor =top_movie_actor[top_movie_actor != 'No cast']
# plotting actor who appeared in highest number of Movie
b = top_movie_actor.value_counts().head(10).plot(kind='barh', ax=ax[1],color='Cyan')
b.set_title('Top 10 Movie actors', size=15)

plt.tight_layout(pad=1.2, rect=[0, 0, 0.95, 0.95])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The horizontal orientation of the bars allows for easier reading and comparison of the values. The length of each bar represents the number of TV shows or movies an actor has appeared in. The chart also includes titles and is divided into two subplots, making it clear that one subplot represents TV shows and the other represents movies.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# In the TV shows category, the actor with the highest appearance is Takahiro Sakurai. In the movies category, the actor with the highest appearance is Anupam Kher.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
top_10_Genre = netflix_movies1['listed_in'].value_counts().head(10)

fig2 = px.pie(top_10_Genre, values=top_10_Genre.values, names=top_10_Genre.index)

custom_colors = ['#4c78a8', '#72b7b2', '#ff7f0e', '#2ca02c', '#d62728']
fig2.update_traces(hovertemplate=None, textposition='outside', textinfo='percent+label', rotation=0,
                   marker=dict(colors=custom_colors))

fig2.update_layout(height=600, width=900, title='Top 10 genres on Netflix',
                   margin=dict(t=100, b=30, l=0, r=0),
                   showlegend=False,
                   plot_bgcolor='#fafafa',
                   paper_bgcolor='#fafafa',
                   title_font=dict(size=20, color='#555', family="Lato, sans-serif"),
                   font=dict(size=12, color='#FF0000'),
                   hoverlabel=dict(bgcolor="#444", font_size=13, font_family="Lato, sans-serif"))

fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The pie chart's circular shape allows viewers to quickly compare the sizes of different genres by observing the relative areas of the slices. The accompanying labels and percentage values outside the slices provi

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# In this chart, the top three genres on Netflix based on their distribution are:
#
# 1-Documentaries: 14.4%
#
# 2-Stand-up Comedy: 13.9%
#
# 3-Drama, International Movies:1 3.8%
#
# These genres have the highest percentages compared to the other genres included in the top 10 list.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights from analyzing the distribution of genres on Netflix can potentially help create a positive business impact in several ways
#
# 1-Content Curation : By focusing on genres that have high viewer demand, Netflix can ensure that it offers a diverse and appealing selection of movies and shows to its subscribers
#
# 2-Targeted Acquisitions and Productions : It can guide them in identifying genres that are in high demand and have a proven audience. This can optimize their investments in content creation and acquisition
#
# 3-Personalized Recommendations: Personalized recommendations for individual users, improving their overall experience and encouraging them to spend more time on the platform.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
# Create subset of dataset with required data.
conuntryVSgenre = netflix_movies1[['country', 'listed_in']]

# Create a function to seperate all genres and store counts for each.
def country_wise_genre(country):
  country_genre = conuntryVSgenre[conuntryVSgenre['country'] == country]
  #Next, the function joins all the genre strings together into a single long string using the ", ".join()
  # method and then splits the long string into a list of individual genre strings using the split() method with ", " as the separator.
  country_genre = ", ".join(country_genre['listed_in'].dropna()).split(", ")
  country_genre_dict = dict(Counter(country_genre))
  return country_genre_dict

# %%
conuntryVSgenre
# Out:
#                                                 country  \
# 0                                                Brazil
# 1                                                Mexico
# 2                                             Singapore
# 3                                         United States
# 4                                         United States
# ...                                                 ...
# 7782  Sweden, Czech Republic, United Kingdom, Denmar...
# 7783                                              India
# 7784                                      United States
# 7785                                          Australia
# 7786              United Kingdom, Canada, United States
#
#                                               listed_in
# 0     International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                          Dramas, International Movies
# 2                   Horror Movies, International Movies
# 3     Action & Adventure, Independent Movies, Sci-Fi...
# ...

# %%
# Define list of top ten countries.
country_list = ['United States', 'India', 'United Kingdom', 'Canada', 'Japan', 'France', 'South Korea', 'Spain', 'Mexico', 'Australia']
# Create an empty dict to store values of each genre for each country.
country_wise_genre_dict = {}
# Iterate through all values in country_list.
for i in country_list:
  genre_data = country_wise_genre(i)
  country_wise_genre_dict[i] = genre_data
  country_genre_count_df = pd.DataFrame(country_wise_genre_dict).reset_index()
  country_genre_count_df.rename({'index':'Genre'}, inplace=True, axis=1)

# %%
country_genre_count_df
# Out:
#                            Genre  United States  India  United Kingdom  \
# 0             Action & Adventure            211  124.0            19.0
# 1             Independent Movies            287  129.0            24.0
# 2               Sci-Fi & Fantasy            102   10.0             6.0
# 3                         Dramas            561  589.0            37.0
# 4                      Thrillers            179   85.0            15.0
# 5         International TV Shows            182   59.0           102.0
# 6                      TV Dramas            262   24.0            21.0
# 7                  Documentaries            425   18.0            79.0
# 8                     Reality TV            136    3.0            32.0
# 9                    TV Comedies            274   25.0            37.0
# 10                      Comedies            500  293.0            31.0
# 11                 Sports Movies             91   15.0            13.0
# ...

# %%
# Plot the above data.
df = country_genre_count_df

# Define colours to be used.
colors = ['aliceblue', 'brown', 'crimson', 'cyan', 'darkblue', 'darkmagenta', 'darkolivegreen', 'darkorange', 'darkturquoise', 'darkviolet', 'deeppink', 'forestgreen',
          'fuchsia', 'gainsboro', 'goldenrod', 'gray','maroon', 'mediumaquamarine', 'mediumvioletred', 'midnightblue', 'orchid', 'palegoldenrod', 'palegreen', 'paleturquoise',
          'plum', 'powderblue', 'purple', 'red', 'rosybrown', 'royalblue', 'saddlebrown', 'salmon', 'sandybrown','seagreen', 'seashell', 'sienna', 'silver', 'slategray', 'snow',
          'springgreen', 'tomato','yellow', 'yellowgreen', 'darkred', 'lavender', 'lightcoral', 'navy', 'olive', 'teal', 'turquoise']


# Create subplots, using 'domain' type for pie charts
specs = [[{'type':'domain'}, {'type':'domain'}, {'type':'domain'}, {'type':'domain'}, {'type':'domain'}], [{'type':'domain'}, {'type':'domain'}, {'type':'domain'}, {'type':'domain'}, {'type':'domain'}]]
fig = make_subplots(rows=2, cols=5, specs=specs, subplot_titles=['United States', 'India', 'United Kingdom', 'Canada', 'Japan', 'France', 'South Korea', 'Spain', 'Mexico', 'Australia'])

# Define traces.
fig.add_trace(go.Pie(labels=df['Genre'], values=df['United States'], name='United States'),1,1)
fig.add_trace(go.Pie(labels=df['Genre'], values=df['India'],  name='India'),1,2)
fig.add_trace(go.Pie(labels=df['Genre'], values=df['United Kingdom'],  name='United Kingdom'),1,3)
fig.add_trace(go.Pie(labels=df['Genre'], values=df['Canada'],  name='Canada'),1,4)
fig.add_trace(go.Pie(labels=df['Genre'], values=df['Japan'],  name='Japan'),1,5)
fig.add_trace(go.Pie(labels=df['Genre'], values=df['France'],  name='France'),2,1)
fig.add_trace(go.Pie(labels=df['Genre'], values=df['South Korea'],  name='South Korea'),2,2)
fig.add_trace(go.Pie(labels=df['Genre'], values=df['Spain'],  name='Spain'),2,3)
fig.add_trace(go.Pie(labels=df['Genre'], values=df['Mexico'],  name='Mexico'),2,4)
fig.add_trace(go.Pie(labels=df['Genre'], values=df['Australia'],  name='Australia'),2,5)

# Tune layout and hover info
fig.update_traces(hoverinfo='label+percent+name', textinfo='none', marker=dict(colors=colors))
fig.update_layout(title={'text': 'Top ten countries and the content they provide.',
                          'y':0.97,
                          'x':0.5,
                          'font_size':25,
                          'xanchor': 'center',
                          'yanchor': 'top'},height=650, width=1550,paper_bgcolor='white',
                  legend=dict(x=0.099,orientation="h")
                          )
fig = go.Figure(fig)
# fig.show()
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# It is suitable for showing the distribution of different genres across multiple countries. Each pie chart represents a country, and the slices of the pie represent different genres. The size of each slice indicates the proportion of content in that genre for a particular country. This allows for easy comparison of genre distribution across countries in a visually appealing manner.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Action & Adventure and Dramas are the most prevalent genres across all countries. They have the highest values in most countries, indicating their popularity.The United States has a diverse content offering across multiple genres, with a strong presence in Action & Adventure, Dramas, Comedies, and Documentaries.
#
# India has a significant focus on Independent Movies and Dramas, with relatively fewer offerings in other genres.
#
# The United Kingdom has a good balance between Drama, International TV Shows, and Documentaries.
#
# Australia's content offering is diverse, with a relatively balanced distribution across various genres such as Dramas, Comedies, International TV Shows, and Documentaries.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights can potentially help create a positive business impact in the following ways:
#
# 1-Targeted Content Strategy: By understanding the genre preferences in different countries, businesses can develop a targeted content strategy that aligns with the interests of their target audience.
#
# 2-Market Expansion:The insights can help businesses identify countries where their content genres are highly popular. This knowledge can guide expansion plans and investment in those markets, increasing the chances of success and profitability.
#
# 3-Content Localization: Understanding the genre preferences in different countries can aid in content localization efforts. Adapting content to suit the local preferences can increase its appeal and viewership, potentially leading to business growth.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
# number of unique values
netflix_movies1['release_year'].nunique()
fig,ax = plt.subplots(1,2, figsize=(15,6))

# Univariate analysis
hist = sns.distplot(netflix_movies1['release_year'], ax=ax[0], kde=False,color='green')
hist.set_title('Distribution by released year', size=20)

# Bivariate analysis
count = sns.countplot(x="release_year", hue='type', data=netflix_movies1, order=netflix_movies1['release_year'].value_counts().index[0:15], ax=ax[1])
count.set_title('Movie/TV shows released in top 15 year', size=15)
plt.xticks(rotation=90)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The chosen chart combination of a histogram and a grouped bar plot allows for both univariate and bivariate analysis. The histogram provides an overview of the distribution of movie release years, while the bar plot allows for a comparison of the number of movies and TV shows released in the top 15 years.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The distribution of release years in the histogram shows a general trend of movies being released on Netflix starting from around 1980. The number of releases gradually increases, with significant growth observed from the year 2000 onwards. The highest peak in the distribution is observed between 2010 and 2020, indicating a high number of Movie/Tv shows releases during that period.
#
# In terms of content type (Movies, TV shows), the bar graph highlights that 2017 and 2020 demonstrate the highest trends. These years exhibit a significant number of movie releases, TV show releases, and a combination of both on Netflix.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the gained insights can help create a positive business impact. By understanding the distribution of release years and identifying trends, businesses can make informed decisions regarding content acquisition, production, and marketing strategies.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
#Ratings
# number of unique values
netflix_movies1.rating.nunique()

fig,ax = plt.subplots(1,2, figsize=(15,6))
plt.suptitle('Top 10 rating for different age groups and audiences & Rating based on Movie and Tv_Shows',
             weight='bold', y=1.02, size=18)

# univariate analysis
sns.countplot(x="rating", data=netflix_movies1, order=netflix_movies1['rating'].value_counts().index[0:10], ax=ax[0])



# bivariate analysis
graph = sns.countplot(x="rating", data=netflix_movies1, hue='type', order=netflix_movies1['rating'].value_counts().index[0:10], ax=ax[1])
plt.xticks(rotation=90)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The chosen chart combination of two count plots allows for both univariate and bivariate analysis. The first plot provides insights into the top 10 ratings across all content, while the second plot offers a comparison of ratings specifically for movies and TV shows.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# TV-MA: This rating means that the content is intended for mature audiences only. It may include graphic violence, explicit sexual content, or strong language
#
# In terms of ratings, the most common rating is TV-MA, which applies to both movies and TV shows.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insight that TV-MA is the most common rating for both movies and TV shows can inform content strategies, audience targeting, programming decisions, and content diversity to drive positive business impact in terms of increased viewership and customer satisfaction

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
netflix_movies1['listed_in'].value_counts().head(25)
import plotly.express as px
import pandas as pd

counts = netflix_movies1['listed_in'].value_counts().head(10)
average = counts.mean()

df = pd.DataFrame({'Category': counts.index, 'Count': counts.values})
colors = px.colors.qualitative.Dark24[:10]
fig = px.bar(df, x='Category', y='Count', color='Category', color_discrete_sequence=colors)
fig.add_hline(y=average, line_color='red')
fig.update_layout(title='Top 10 Average Genere with Count',title_x=0.3)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The chosen chart effectively presents the data, allowing viewers to easily compare the Average counts of different genres.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The average count of genres in the top 10 categories lies between 200-250. The genre with the highest count among all the genres is Documentaries, with a count of 334.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the gained insights can help create a positive business impact for a streaming platform like Netflix or any other company in the entertainment industry.These insights, companies can refine their content strategies, enhance viewer satisfaction, attract a larger audience, and ultimately drive positive business impact in terms of increased viewership, customer retention, and revenue growth

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
# Word Cloud for Titles
from wordcloud import WordCloud
title_words = ' '.join(netflix_movies1['title']).lower()
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(title_words)
plt.figure(figsize=(10, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud for Titles')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The word cloud chart was chosen to visually represent the frequency of words in the titles of Netflix movies in a creative and engaging manner.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The word cloud chart visually emphasizes the most frequent words in the titles of Netflix movies, providing insight into recurring themes or popular topics within the movie titles. This can offer an at-a-glance view of common trends or subjects that are prevalent in the movie titles on Netflix.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights gained from the word cloud chart can potentially help create a positive business impact by identifying popular themes or topics that resonate with viewers, thereby informing content creation strategies. However, if there are recurring negative themes or topics in movie titles, it could potentially lead to negative growth as these may not be appealing to the audience, impacting viewership and engagement.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
# Selecting numerical columns for correlation analysis
numerical_cols = netflix_movies1.select_dtypes(include=['int64', 'float64'])

# Calculating correlation matrix
correlation_matrix = numerical_cols.corr()

# Plotting the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The specific chart, a correlation heatmap, was chosen due to its effectiveness in displaying the complex relationships and interactions between numerical variables in the dataset. This visualization method offers a comprehensive and visually intuitive way to observe the strength and direction of correlations, providing a clear understanding of how different variables relate to each other.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The correlation heatmap reveals the degree of correlation between numerical columns. Insights include identifying strong positive or negative correlations, which can help in understanding potential associations or dependencies between different attributes in the dataset.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
# Selecting variables for pair plot
selected_vars = ['release_year', 'duration', 'rating']

# Creating pair plot
sns.pairplot(netflix_movies1[selected_vars])
plt.suptitle('Pair Plot of Selected Variables', y=1.02)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The pair plot was chosen for its ability to showcase relationships between selected variables in a visually comprehensive manner. This type of chart is well-suited for displaying pairwise relationships and distributions across numerical variables in a dataset, offering insights into potential correlations and patterns between the chosen attributes.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The pair plot highlights potential relationships and distributions between the selected variables. Through this visualization, one can gain insight into patterns such as the relationship between release year and duration, as well as the distribution of ratings across different release years.

# %% [markdown]
# ## ***5. Hypothesis Testing***

# %% [markdown]
# ### Based on your chart experiments, define three hypothetical statements from the dataset. In the next three questions, perform hypothesis testing to obtain final conclusion about the statements through your code and statistical testing.

# %% [markdown]
# ### Hypothetical Statement - 1

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# HO:Movies rated for kids and older kids are at least two hours long.(Null Hypothesis)
#
# H1:Movies rated for kids and older kids are not at least two hours long.(Alternate Hypothesis)

# %%
#making copy of df_clean_frame
netflix_hypothesis=netflix_movies1.copy()
#head of df_hypothesis
netflix_hypothesis.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   date_added  release_year rating   duration  \
# 0 2020-08-14          2020  TV-MA  4 Seasons
# 1 2016-12-23          2016  TV-MA     93 min
# 2 2018-12-20          2011      R     78 min
# 3 2017-11-16          2009  PG-13     80 min
# 4 2020-01-01          2008  PG-13    123 min
#
# ...

# %%
#filtering movie from Type_of_show column
netflix_hypothesis = netflix_hypothesis[netflix_hypothesis["type"] == "Movie"]

# %%
#with respect to each ratings assigning it into group of categories
ratings_ages = {
    'TV-PG': 'Older Kids',
    'TV-MA': 'Adults',
    'TV-Y7-FV': 'Older Kids',
    'TV-Y7': 'Older Kids',
    'TV-14': 'Teens',
    'R': 'Adults',
    'TV-Y': 'Kids',
    'NR': 'Adults',
    'PG-13': 'Teens',
    'TV-G': 'Kids',
    'PG': 'Older Kids',
    'G': 'Kids',
    'UR': 'Adults',
    'NC-17': 'Adults'
}

netflix_hypothesis['target_ages'] = netflix_hypothesis['rating'].replace(ratings_ages)
#let's see unique target ages
netflix_hypothesis['target_ages'].unique()
# Out:
# array(['Adults', 'Teens', 'Older Kids', 'Kids', nan], dtype=object)

# %%
netflix_hypothesis['target_ages'] = pd.Categorical(netflix_hypothesis['target_ages'], categories=['Kids', 'Older Kids', 'Teens', 'Adults'])

netflix_hypothesis['duration'] = netflix_hypothesis['duration'].astype(str)  # Convert to string type
netflix_hypothesis['duration'] = netflix_hypothesis['duration'].str.extract('(\d+)')
netflix_hypothesis['duration'] = pd.to_numeric(netflix_hypothesis['duration'])

netflix_hypothesis.head(3)
# Out:
#   show_id   type  title           director  \
# 1      s2  Movie   7:19  Jorge Michel Grau
# 2      s3  Movie  23:59       Gilbert Chan
# 3      s4  Movie      9        Shane Acker
#
#                                                 cast        country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
#
#   date_added  release_year rating  duration  \
# 1 2016-12-23          2016  TV-MA        93
# 2 2018-12-20          2011      R        78
# 3 2017-11-16          2009  PG-13        80
#
#                                            listed_in  \
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
#
#                                          description  day_added  year_added  \
# ...

# %%
#group_by duration and target_ages
group_by_= netflix_hypothesis[['duration','target_ages']].groupby(by='target_ages')
#mean of group_by variable
group=group_by_.mean().reset_index()
group
# Out:
#   target_ages    duration
# 0        Kids   66.486891
# 1  Older Kids   92.024648
# 2       Teens  110.025332
# 3      Adults   98.275145

# %%
from scipy import stats

# %%
#length of groups and DOF
#In A and B variable grouping values
A= group_by_.get_group('Kids')
B= group_by_.get_group('Older Kids')
n1 = len(A)
n2= len(B)
dof = n1+n2-2
print('dof',dof)
# Out:
# dof 1117

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value
#t-distribution
stats.t.ppf(0.025,dof)
# Out:
# -1.9620900365868952

# %%
#t-distribution
stats.t.ppf(0.975,dof)
# Out:
# 1.9620900365868947

# %% [markdown]
# t-value is not in the range, the null hypothesis is rejected.
#
# As a result, movies rated for kids and older kids are not at least two hours long.

# %% [markdown]
# ### Hypothetical Statement - 2

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# H1:The duration which is more than 90 mins are movies
#
# HO:The duration which is more than 90 mins are NOT movies

# %%
#making copy of df_clean_frame
netflix_hypothesis=netflix_movies1.copy()

netflix_hypothesis['duration']= netflix_hypothesis['duration'].str.extract('(\d+)')
netflix_hypothesis['duration'] = pd.to_numeric(netflix_hypothesis['duration'])

netflix_hypothesis['type'] = pd.Categorical(netflix_hypothesis['type'], categories=['Movie','TV Show'])
#from duration feature extractin string part and after extracting Changing the object type to numeric
#df_hypothesis['duration']= df_hypothesis['duration'].str.extract('(\d+)')
#df_hypothesis['duration'] = pd.to_numeric(df_hypothesis['duration'])
#head of df_
netflix_hypothesis.head(3)

netflix_hypothesis['type'] = pd.Categorical(netflix_hypothesis['type'], categories=['Movie','TV Show'])

# Perform Statistical Test to obtain P-Value
#group_by duration and TYPE
group_by_= netflix_hypothesis[['duration','type']].groupby(by='type')
#mean of group_by variable
group1=group_by_.mean().reset_index()
group1
# Out:
#       type   duration
# 0    Movie  99.307978
# 1  TV Show   1.775934

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value
#t-distribution
stats.t.ppf(0.025,dof)
# Out:
# -1.9620900365868952

# %%
#t-distribution
stats.t.ppf(0.975,dof)
# Out:
# 1.9620900365868947

# %% [markdown]
# Because the t-value is not in the range, the null hypothesis is rejected.
#
# As a result, The duration which is more than 90 mins are movies

# %% [markdown]
# ### Hypothetical Statement - 3

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# **Null Hypothesis (H0):** The mean duration of movies is equal to the mean duration of TV shows.
#
# **Alternative Hypothesis (H1):** The mean duration of movies is not equal to the mean duration of TV shows.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value
from scipy.stats import ttest_ind, mannwhitneyu

# Extract durations for movies and TV shows
movie_durations = netflix_hypothesis[netflix_hypothesis['type'] == 'Movie']['duration']
tv_show_durations = netflix_hypothesis[netflix_hypothesis['type'] == 'TV Show']['duration']

# Perform t-test assuming unequal variances
t_stat, p_value = ttest_ind(movie_durations, tv_show_durations, equal_var=False)

# Perform Mann-Whitney U test as a non-parametric alternative
u_stat, p_value_mannwhitney = mannwhitneyu(movie_durations, tv_show_durations)

# Print the results
print("T-test p-value:", p_value)
print("Mann-Whitney U test p-value:", p_value_mannwhitney)
# Out:
# T-test p-value: 0.0
# Mann-Whitney U test p-value: 0.0

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# **Independent Two-Sample T-test:**
#
# The independent two-sample t-test (ttest_ind) was conducted assuming unequal variances (equal_var=False). This test compares the means of two independent samples to determine whether they are significantly different from each other.
# T
# he obtained p-value from the t-test was used to assess the significance of the difference in mean durations between movies and TV shows.
#
# **Mann-Whitney U Test:**
#
# The Mann-Whitney U test (mannwhitneyu) is a non-parametric alternative to the t-test and is suitable for comparing two independent samples when the assumptions of normality and equal variances are not met.
# This test assesses whether there is a significant difference in the distributions of the two samples, regardless of their shapes or variances.
#
# The p-value obtained from the Mann-Whitney U test provided additional evidence regarding the significance of the difference in durations between movies and TV shows.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# The independent two-sample t-test was chosen because it is appropriate for comparing the means of two independent samples (movie durations and TV show durations) when the data is approximately normally distributed and the variances may not be equal. This test provides insights into whether there is a significant difference in the average durations between movies and TV shows. Additionally, the Mann-Whitney U test was selected as a non-parametric alternative to validate the results, as it does not rely on the assumptions of normality and equal variances, providing robustness to potential violations of these assumptions.

# %% [markdown]
# ## ***6. Feature Engineering & Data Pre-processing***

# %%
# Combining all the clustering attributes into a single column
netflix_movies1['clustering'] = (netflix_movies1['director'] + ' ' + netflix_movies1['cast'] +' ' +
                                 netflix_movies1['country'] +' ' + netflix_movies1['listed_in'] +
                                 ' ' + netflix_movies1['description'])

# %%
netflix_movies1['clustering'][25]
# Out:
# 'Lyric R. Cabral, David Felix Sutcliffe No cast United States Documentaries This real-life look at FBI counterterrorism operations features access to both sides of a sting: the government informant and the radicalized target.'

# %% [markdown]
# ### Textual Data Preprocessing
#
#
#
#
# (It's mandatory for textual dataset i.e., NLP, Sentiment Analysis, Text Clustering etc.)

# %%
# Expand Contraction
# Lower Casing
# Remove Punctuations
# Remove URLs & Remove words and digits contain digits
# Remove Stopwords
# Remove White spaces
# Rephrase Text
# Tokenization
# Normalizing Text (i.e., Stemming, Lemmatization etc.)

import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
import string
import nltk
nltk.download('all',quiet=True)
from PIL import Image

def transform_text(text):
    # Convert text to lowercase
    text = text.lower()

    # Remove URLs
    text = re.sub(r'http\S+', '', text)

    # Tokenize text into words
    words = nltk.word_tokenize(text)

    # Remove non-alphanumeric characters
    words = [word for word in words if word.isalnum()]

    # Remove stopwords and punctuation
    stopwords_set = set(stopwords.words('english'))
    punctuation_set = set(string.punctuation)
    words = [word for word in words if word not in stopwords_set and word not in punctuation_set]

    # Lemmatize words
    lemmatizer = WordNetLemmatizer()
    lemmatized_words = [lemmatizer.lemmatize(word) for word in words]

    # Join words into a string and return
    return ' '.join(lemmatized_words)

# %%
# Check if the "Clean_Text" column exists
if "Clean_Text" in netflix_movies1.columns:
    # Column exists, proceed with the code
    bag_of_words = netflix_movies1["Clean_Text"]
else:
    # Column does not exist, create it
    netflix_movies1["Clean_Text"] = netflix_movies1["description"].apply(transform_text)
    bag_of_words = netflix_movies1["Clean_Text"]

# %%
t_vectorizer = TfidfVectorizer(max_features=20000)
X= t_vectorizer.fit_transform(bag_of_words)

# %%
print(X.shape)
# Out:
# (7787, 15681)

# %%
t_vectorizer.get_feature_names_out()
# Out:
# array(['007', '009', '10', ..., 'łukasz', 'ōarai', 'şeref'], dtype=object)

# %% [markdown]
# ###  Data Transformation

# %% [markdown]
# #### Do you think that your data needs to be transformed? If yes, which transformation have you used. Explain Why?

# %%
# Transform Your data
# Import the necessary libraries
from sklearn.decomposition import PCA

# Assuming X is your original input data
# Let's assume X is your original input data and you want to apply PCA to only half of it
half_of_data = X[:X.shape[0] // 4]  # Use only half of half data

# Create an instance of PCA with the desired explained variance ratio
pca_tuned = PCA(n_components=0.95)

# Fit the PCA model on the subset of the input data
pca_tuned.fit(half_of_data.toarray())

# Transform the subset of the input data to its reduced dimensional representation
X_transformed = pca_tuned.transform(half_of_data.toarray())

# Print the shape of the transformed data to see the number of samples and transformed features
print(X_transformed.shape)
# Out:
# (1946, 1628)

# %% [markdown]
# ### Dimesionality Reduction

# %% [markdown]
# ##### Do you think that dimensionality reduction is needed? Explain Why?

# %% [markdown]
# PCA to reduce the dimensionality of the dataset. PCA identifies the directions (principal components) along which the data varies the most. These components are ordered by the amount of variance they explain in the data.

# %%
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Assuming X is your data (features) represented as a sparse matrix

# Calculate the number of samples for 25% of the data
n_samples_25 = int(0.25 * X.shape[0])

# Randomly select 25% of the data
indices_25 = np.random.choice(X.shape[0], n_samples_25, replace=False)
X_25 = X[indices_25]

# Perform PCA on the selected 25% of the data
transformer_25 = PCA()
transformer_25.fit(X_25.toarray())

# Plot explained variance ratio
plt.figure(figsize=(10, 6))
plt.plot(np.cumsum(transformer_25.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance Ratio')
plt.title('Explained Variance Ratio for 25% of the Data')

plt.axhline(y=0.95, color='r', linestyle='--',linewidth=2, label='95% Explained Variance')
plt.grid()
plt.show()

# %% [markdown]
# ##### Which dimensionality reduction technique have you used and why? (If dimensionality reduction done on dataset.)

# %% [markdown]
# PCA can extract the most relevant features from a dataset. It transforms the original features into a new set of uncorrelated variables called principal components. These components are linear combinations of the original features and capture the maximum amount of variation present in the data.

# %% [markdown]
# The plot helps in determining the number of components to consider for dimensionality reduction. You can select the number of components where the cumulative explained variance reaches a satisfactory threshold, such as 95%. The point where the curve intersects or is closest to the threshold line can guide you in choosing the appropriate number of components for your analysis.

# %% [markdown]
# ###  Data Splitting

# %%
# Split your data to train and test. Choose Splitting ratio wisely.
from sklearn.model_selection import train_test_split

# Assuming X is your feature data
X_train, X_test = train_test_split(X, test_size=0.2, random_state=42)
# Use 0.2 or 0.3 for the test_size parameter to represent a 80/20 or 70/30 split respectively

# %% [markdown]
# ##### What data splitting ratio have you used and why?

# %% [markdown]
# I've used an 80/20 data splitting ratio, with 80% of the data allocated for training and 20% for testing. This selection aims to strike a balance between having sufficient data for training the model while still retaining a significant portion for testing and evaluation. This split is commonly chosen to ensure that the model is trained on a substantial amount of data, enhancing its ability to capture underlying patterns and relationships in the training set.
#
# Using a smaller portion for testing helps to maintain an adequate number of samples for training, which is crucial for building a robust model. Additionally, having a meaningful amount of data for testing enables a more reliable assessment of the model's generalization and predictive performance on unseen data.
#
# While a 70/30 split (70% for training and 30% for testing) is also a valid choice and provides more data for training, it might result in a smaller test set, potentially leading to less reliable performance estimates. Therefore, the 80/20 split strikes a reasonable balance between model training and validation, making it a commonly used ratio in practice.

# %% [markdown]
# ###  Handling Imbalanced Dataset

# %%
from sklearn.ensemble import IsolationForest
import pandas as pd
import numpy as np

# Assuming X is your feature data
# X represents your original feature data

# Create an Isolation Forest model
model = IsolationForest(contamination='auto', random_state=42)  # contamination is the expected proportion of outliers

# Fit the model to the data
model.fit(X)

# Predict outliers/anomalies
outlier_preds = model.predict(X)

# Identify the outliers
outliers = X[outlier_preds == -1]  # Selecting the instances predicted as outliers

# Work with the outliers (e.g., further analysis, removal, or labeling as anomalies)
# You might apply domain-specific knowledge to determine the importance and appropriate handling of these outliers

# %% [markdown]
# ##### Do you think the dataset is imbalanced? Explain Why.

# %% [markdown]
# Based on the utilization of Isolation Forest for outlier detection, it implies the possibility of imbalance within the dataset. Isolation Forest identifies anomalies or outliers as data points that are distinctly different from the majority of the dataset. The detection of outliers suggests that there are relatively few instances that significantly deviate from the main distribution of the data.
#
# In this context, the dataset is likely considered imbalanced due to the presence of these outlier/anomalous instances, which are expected to be a small proportion relative to the majority of the data. The Isolation Forest model targets and flags these uncommon instances, indicating that a disparity exists between the regular data points and these outliers.

# %% [markdown]
# ##### What technique did you use to handle the imbalance dataset and why? (If needed to be balanced)

# %% [markdown]
# In the provided code, there is no explicit technique applied to handle the imbalance within the dataset. However, if handling the imbalanced nature of the dataset is necessary, techniques such as oversampling, undersampling, or the use of algorithms specifically designed to handle imbalanced datasets could be considered.
#
# For addressing imbalanced datasets, one common and effective technique is to use resampling methods such as:
#
# Oversampling: This involves creating additional synthetic instances of the minority class to rebalance the distribution. Techniques like SMOTE (Synthetic Minority Over-sampling Technique) generate synthetic samples to supplement the minority class.
# Undersampling: In this approach, the majority class data points are subsampled to reduce their dominance in the dataset, achieving a more balanced class distribution.
# Another approach is to use algorithms designed to handle imbalanced datasets, such as:
#
# Ensemble Methods: Algorithms like Random Forest, AdaBoost, or XGBoost often handle class imbalances effectively by adjusting the learning process to focus more on the minority class.
# The choice of technique depends on the specifics of the dataset and the problem at hand. It's essential to assess the impact of these techniques on the performance of the model before implementing them in practice.

# %% [markdown]
# ## ***7. ML Model Implementation***

# %% [markdown]
# ### ML Model - 1

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer

# Initialize the KMeans model with a random_state of 5
model = KMeans(random_state=5)

# Initialize the KElbowVisualizer with the KMeans model and desired parameters
visualizer = KElbowVisualizer(model, k=(4, 22), metric='silhouette', timings=False, locate_elbow=True)

# Fit the visualizer on the transformed data
visualizer.fit(X_transformed)

# Display the elbow plot
visualizer.show()
# Out:
# <Axes: title={'center': 'Silhouette Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='silhouette score'>

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
from sklearn.cluster import KMeans
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import silhouette_score
from sklearn.metrics import make_scorer

# Assuming X is your feature data
model = KMeans(random_state=42)

# Define the parameter grid to search
param_grid = {'n_clusters': [3, 4, 5, 6, 7]}  # Example range of n_clusters to search over

# Define silhouette score as the scoring function
scorer = make_scorer(silhouette_score)

# Initialize GridSearchCV with the defined model, parameter grid, and scoring function
grid_search = GridSearchCV(model, param_grid, scoring=scorer, cv=5)

# Fit the GridSearchCV to the data
grid_search.fit(X)

# View the best parameters and the best silhouette score
print("Best Parameters:", grid_search.best_params_)
print("Best Silhouette Score:", grid_search.best_score_)
# Out:
# Best Parameters: {'n_clusters': 3}
# Best Silhouette Score: nan

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import silhouette_score
import numpy as np

# Initialize the KMeans model with the selected number of clusters
model = KMeans(n_clusters=3, random_state=42)

# Perform cross-validation manually to calculate silhouette scores
silhouette_scores = []
for train_index, test_index in KFold(n_splits=5, shuffle=True, random_state=42).split(X):
    X_train, X_test = X[train_index], X[test_index]
    clusters = model.fit_predict(X_train)
    score = silhouette_score(X_train, clusters)
    silhouette_scores.append(score)

# Convert silhouette_scores to array
silhouette_scores = np.array(silhouette_scores)

# View the cross-validation silhouette scores
print("Cross-Validation Silhouette Scores:", silhouette_scores)
print("Mean Cross-Validation Silhouette Score:", silhouette_scores.mean())
# Out:
# Cross-Validation Silhouette Scores: [0.00141769 0.00109762 0.00108166 0.00118349 0.00140243]
# Mean Cross-Validation Silhouette Score: 0.0012365765071264399

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# The provided code demonstrates two hyperparameter optimization techniques:
#
#
# **GridSearchCV:**
# Utilizes GridSearchCV to find the optimal number of clusters (n_clusters) for the KMeans algorithm.
# Defines a parameter grid (param_grid) specifying the range of values to search over for n_clusters.
# Uses silhouette score as the scoring function to evaluate the performance of each set of hyperparameters.
# Fits the GridSearchCV object to the data (X) to determine the best set of hyperparameters.
#
# Prints the best parameters and corresponding silhouette score for model evaluation.
# Manual Cross-Validation with Silhouette
#
# **Scores:**
# Initializes the KMeans model with a predefined number of clusters (n_clusters=3).
# Performs manual cross-validation using KFold to split the data into training and validation sets.
# Fits the KMeans model to the training data for each fold and computes the silhouette score.
#
# Collects and averages the silhouette scores from each fold to obtain the mean cross-validation silhouette score.
# This approach offers an alternative method to evaluate the KMeans model's performance with a specific number of clusters using silhouette scores.
#
# Both techniques aim to optimize the KMeans clustering algorithm's hyperparameters, with GridSearchCV providing an automated search over a predefined parameter grid and manual cross-validation offering more control over the evaluation process.

# %% [markdown]
# ### ML Model - 2

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# Create a figure with a specific size and resolution
plt.figure(figsize=(10, 6), dpi=120)

# Initialize an empty list to store the within-cluster sum of squares (WCSS)
wcss = []

# Iterate over different numbers of clusters
for i in range(1, 22):
    # Create a KMeans model with default parameters
    model = KMeans(random_state=0)

    # Initialize the KMeans algorithm with specific parameters
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)

    # Fit the KMeans algorithm to the transformed data
    kmeans.fit(X_transformed)

    # Append the WCSS to the list
    wcss.append(kmeans.inertia_)

# Plot the number of clusters against the WCSS
plt.plot(range(1, 22), wcss)

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
from sklearn.cluster import KMeans
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
from sklearn.metrics import silhouette_score
import numpy as np

# Initialize an empty list to store silhouette scores
silhouette_scores = []

# Iterate over different numbers of clusters
for i in range(2, 10):
    # Create a KMeans model with a specific number of clusters
    model = KMeans(n_clusters=i, random_state=0)

    # Fit the KMeans model to the data and obtain cluster assignments
    cluster_assignments = model.fit_predict(X_transformed)

    # Compute the silhouette score
    silhouette_avg = silhouette_score(X_transformed, cluster_assignments)
    silhouette_scores.append(silhouette_avg)

# Find the optimal number of clusters with the highest silhouette score
optimal_n_clusters = np.argmax(silhouette_scores) + 2  # Add 2 as we started the loop from 2

# Now that you have the optimal number of clusters, you can use GridSearchCV for hyperparameter tuning
param_grid = {'n_clusters': range(2, 10)}  # Example range of n_clusters to search over
model = KMeans(random_state=42)
scorer = make_scorer(silhouette_score)
grid_search = GridSearchCV(model, param_grid, scoring=scorer, cv=5)
grid_search.fit(X_transformed)

# View the best parameters and the best silhouette score
print("Best Parameters:", grid_search.best_params_)
print("Best Silhouette Score:", grid_search.best_score_)
# Out:
# Best Parameters: {'n_clusters': 2}
# Best Silhouette Score: nan

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# The hyperparameter optimization technique used in the provided code is a combination of manual iteration over different numbers of clusters and then applying GridSearchCV for further refinement.
#
# **Here's how it works:**
#
# **Manual Iteration:**
#
# The code iterates over different numbers of clusters (from 2 to 9) using a for loop.
# For each iteration, a KMeans model is created with the specified number of clusters, and the model is fitted to the transformed data (X_transformed).
# The silhouette score is computed for each clustering configuration using the silhouette_score function from sklearn.metrics.
# The silhouette scores are stored in a list for later analysis.
#
#
# **Finding Optimal Number of Clusters:**
#
#
# After iterating over different numbers of clusters, the code identifies the optimal number of clusters by selecting the one with the highest silhouette score.
# The optimal number of clusters is determined by finding the index of the maximum silhouette score in the list of silhouette scores and adding 2 (since the loop starts from 2).
#
# **GridSearchCV:**
#
# Once the optimal number of clusters is determined, GridSearchCV is used to perform hyperparameter tuning for the KMeans model.
# The param_grid specifies a range of values for the number of clusters to search over.
# GridSearchCV is configured with the silhouette_score as the scoring function, and it uses 5-fold cross-validation (cv=5) to evaluate the performance of each set of hyperparameters.
#
# The best parameters and the corresponding best silhouette score are printed to evaluate the performance of the optimized model.
#
# This approach combines manual iteration for an initial exploration of different cluster numbers with GridSearchCV for a more systematic hyperparameter search. It leverages the silhouette score as a measure of clustering quality, aiming to find the optimal number of clusters and hyperparameters for the KMeans model.

# %% [markdown]
# #### 3. Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# **Precision:**
# Precision indicates the accuracy of positive predictions. It's crucial in scenarios where false positives have significant consequences, such as fraud detection. High precision ensures that flagged instances are genuinely positive, reducing false alarms and operational costs.
#
# **Recall (Sensitivity):**
#
#  Recall measures the model's ability to capture all positive instances. In applications like medical diagnosis, high recall ensures that no positive cases are missed, minimizing the risk of overlooking critical issues and maximizing opportunities.
#
# **F1-Score:**
#
# The F1-score balances precision and recall, providing a comprehensive measure of model performance. It's valuable when both precision and recall are essential, helping to identify models that strike the right balance between accuracy and completeness.
#
# **Accuracy:**
#
# Accuracy reflects the overall correctness of the model's predictions. While widely used, its interpretation depends on context. Nonetheless, high accuracy suggests that the model performs well overall, benefiting various business applications.
# Specificity: Specificity focuses on the model's ability to correctly identify negative instances. It complements recall by ensuring accurate detection of non-relevant cases, crucial in fields like medical testing or quality control to reduce false alarms and improve decision-making accuracy.

# %% [markdown]
# ### ML Model - 3

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import numpy as np

# Create a figure with a larger size and resolution
plt.figure(figsize=(20, 8), dpi=120)

# Initialize a KMeans model with 15 clusters
kmeans = KMeans(n_clusters=15, init='k-means++', random_state=9)

# Fit the KMeans algorithm to the transformed data
kmeans.fit(X_transformed)

# Predict the labels of the clusters
label = kmeans.fit_predict(X_transformed)

# Get unique labels from the predictions
unique_labels = np.unique(label)

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart
# Plot the results
for i in unique_labels:
    # Scatter plot the points belonging to each cluster
    plt.scatter(X_transformed[label == i, 0], X_transformed[label == i, 1], label=i)

# Display a legend to identify the clusters
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, silhouette_score
import numpy as np

# Initialize the KMeans model
kmeans = KMeans(random_state=9)

# Define the parameter grid to search
param_grid = {'n_clusters': [10, 15, 20, 25]}  # Example range of n_clusters to search over

# Create a silhouette scorer for use in GridSearchCV
scorer = make_scorer(silhouette_score)

# Initialize GridSearchCV with the defined model, parameter grid, and scoring function
grid_search = GridSearchCV(kmeans, param_grid, scoring=scorer, cv=5)

# Fit the GridSearchCV to the transformed data
grid_search.fit(X_transformed)

# View the best parameters and the best silhouette score
print("Best Parameters:", grid_search.best_params_)
print("Best Silhouette Score:", grid_search.best_score_)
# Out:
# Best Parameters: {'n_clusters': 10}
# Best Silhouette Score: nan

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# 1. **Comprehensive Search:** GridSearchCV rigorously explores a specified parameter grid, exhaustively identifying the best hyperparameter combination without resorting to random chance. This thorough approach becomes particularly valuable in scenarios where the dataset is not extensive, ensuring thorough exploration of potential hyperparameter configurations.
#
# 2. **Scoring Flexibility:** GridSearchCV allows for the incorporation of custom scoring functions, providing adaptability to diverse use cases. Leveraging the silhouette score as the evaluation metric in the provided code aligns the optimization process with clustering tasks, demonstrating GridSearchCV's capacity to seamlessly integrate tailored scoring metrics.
#
# 3. **Cross-Validation Integration:** Default inclusion of cross-validation within GridSearchCV assures robust model evaluation, steering clear of overfitting while delivering accurate estimates of predictive performance. This feature promotes the reliability of the entire hyperparameter optimization process.
#
# 4. **Scalability:** GridSearchCV's efficiency extends to managing larger parameter spaces, guaranteeing its applicability across a wide spectrum of hyperparameter optimization scenarios. As evident, its capacity to handle complex parameter configurations underscores its versatility and scalability.
#
# In conclusion, GridSearchCV presents a methodical and robust approach to hyperparameter optimization. Its reliance on cross-validation and configurable scoring functions positions it as a dependable tool for identifying the optimal hyperparameters for a given model.

# %% [markdown]
# ### 1. Which Evaluation metrics did you consider for a positive business impact and why?

# %% [markdown]
# The choice to use the silhouette score as the evaluation metric for hyperparameter optimization within KMeans clustering aligns with the focus on positive business impact for several reasons within the context of unsupervised learning:
#
# 1. **Relevance to Clustering Tasks**: The silhouette score is specifically tailored to evaluating clustering tasks, providing a robust measure of how well individual data points lie within their clusters. By optimizing for this metric, the model aims to achieve well-defined, separate clusters, directly aligning with the business goal of identifying distinct customer segments or operational clusters. This enhances the practical application of clustering outputs in real-world business contexts.
#
# 2. **Informed Decision-Making**: Improving silhouette scores contributes to better-formed clusters, directly impacting strategic decision-making. The insights derived from well-defined clusters can drive targeted advertising, optimized product positioning, and personalized offerings, directly influencing customer engagement and sales. This directly corresponds to the core business objective of achieving stronger customer relations and revenue growth.
#
# 3. **Efficient Resource Allocation**: Optimized clustering, reflected by higher silhouette scores, facilitates streamlined resource allocation across various business operations, such as inventory management, service distribution, or customer support. Well-defined clusters hold the potential to maximize resource utilization and operational efficiency, thereby positively impacting the bottom line.
#
# 4. **Enhanced Customer Understanding**: The silhouette score aids in gaining deeper insights into customer behavior and preferences, enabling the development of tailored marketing strategies, product enhancements, and service improvements. Ultimately, this fosters a more satisfied customer base and improved customer loyalty, aligning with the overarching business objective of enhancing customer relations and retention.
#
# 5. **Scalability and Adaptability**: The silhouette score's versatility and adaptability across diverse industries make it a valuable metric for eliciting positive business impact in a variety of applications, such as retail, e-commerce, healthcare, and finance. This underscores the metric's potential to provide meaningful insights and drive impactful decisions across different sectors.
#
# By considering the silhouette score, the evaluation process directly converges with the overarching business objective of leveraging data-driven insights to optimize segmentation, resource utilization, and customer-focused strategies. This alignment demonstrates the direct contribution of unsupervised learning, specifically clustering, to realizing positive business impacts across a wide range of operational and strategic domains.

# %% [markdown]
# ### 2. Which ML model did you choose from the above created models as your final prediction model and why?

# %% [markdown]
# The rationale for choosing the KMeans clustering model with optimized hyperparameters as the final prediction model, especially in the context of unsupervised learning, is highly compelling. Let's break down the reasoning for choosing this model further:
#
# 1. **Domain Relevance**: KMeans clustering is directly applicable to a wide range of business tasks such as customer segmentation, product categorization, and anomaly detection. Its flexibility and adaptability make it suitable for various business applications, allowing for the extraction of meaningful insights from unlabeled data, ultimately serving the business's needs and objectives.
#
# 2. **Interpretability**: KMeans provides transparent and understandable results, aiding business stakeholders in comprehending the derived clusters, cluster assignments, and centroid characteristics. This interpretability is essential for generating actionable insights and establishing strategies that are rooted in data-derived patterns and groupings.
#
# 3. **Scalability and Efficiency**: KMeans' reputation for scalability and efficiency ensures its practical application to large datasets commonly encountered in business operations. Its ability to handle substantial volumes of data promotes its utility across diverse business scenarios, allowing for the processing of real-world data at scale.
#
# 4. **Integration with Business Goals**: The tailored KMeans clustering model with optimized hyperparameters directly contributes to informed decision-making, efficient resource allocation, and the development of customer-centric strategies. By aligning with business goals, the model fosters positive impacts through its ability to yield valuable insights from unlabelled data.

# %% [markdown]
# # 3. Explain the model which you have used and the feature importance using any model explainability tool?

# %% [markdown]
# For unsupervised learning models like KMeans, traditional feature importance metrics commonly applied to supervised models (such as coefficients in linear regression or feature importances in decision trees) are not applicable due to the nature of unsupervised learning. As such, feature importance in the traditional sense is not directly available.
#
# However, in the context of KMeans or other unsupervised models, interpretability often centers on understanding cluster characteristics and the relative importance of features in defining these clusters. While there are no direct "feature importance" tools akin to those in supervised learning, there are techniques that can aid in understanding unsupervised models:
#
# 1. **Dimensionality Reduction Techniques:** Tools like Principal Component Analysis (PCA) can help visualize the relative importance of features by showing how they contribute to the definition of clusters in lower-dimensional space. This approach aids in understanding which features contribute most to the variation in the data.
#
# 2. **Visualizing Cluster Centroids:** Visualizing the centroids of the clusters and their relationships with features can provide insights into feature importance. This can involve analyzing how features vary across different clusters and which features contribute most to the separation of clusters.
#
# 3. **Domain-specific Insights:** Sometimes, domain knowledge and expertise are essential in understanding the relative importance of features within an unsupervised context. These insights can provide a qualitative understanding of the role each feature plays in defining clusters or patterns within the data.
#
# While directly calculating feature importance in the traditional sense is not feasible for unsupervised learning, these methodologies offer paths to interpretability and understanding, aiding in uncovering the importance of features within the context of clustering and unsupervised learning.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# **1 -**It is interesting to note that the majority of the content available on Netflix consists of movies. However, in recent years, the platform has been focusing more on TV shows.
#
# **2 -** Most of these shows are released either at the end or the beginning of the year.
#
# **3 -** The United States and India are among the top five countries that produce all of the available content on the platform. Additionally, out of the top ten actors with the maximum content, six of them are from India.
#
# **4 -** When it comes to content ratings, TV-MA tops the charts, indicating that mature content is more popular on Netflix.
#
# **5 -** The value of k=15 was found to be optimal for clustering the data, and it was used to group the content into ten distinct clusters.
#
# **6 -** Using this data, a Content based recommender system was created using cosine similarity, which provided recommendations for Movies and TV shows.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your Machine Learning Capstone Project !!!***
